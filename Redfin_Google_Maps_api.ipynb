# %% [markdown]
# # Bridge MLS Data 🌉

# %%
#Import libraries
import pandas as pd
import numpy as np
import json
import requests

# %%
dataset_id = 'bridgemls'
server_token = '4c71c15af9f486c827e0307b79d0582a'
resource = 'property'

#r = requests.get(f'https://api.bridgedataoutput.com/api/v2/{dataset_id}/{resource}?access_token={server_token}')
r = requests.get('https://api.bridgedataoutput.com/api/v2/dataset_id/listings?access_token=access_token')

# %%
r
# Out:
# <Response [403]>

# %%
resource
# Out:
# 'properties'

# %% [markdown]
# # RapidAPI

# %%
import requests

url = "https://mashvisor-api.p.rapidapi.com/rental-rates"

querystring = {"state":"CA","source":"airbnb","city":"Los Angeles","zip_code":"90291"}

headers = {
	"X-RapidAPI-Key": "552c8e0a5emsh03eb078a5d59bdap1e9190jsn571dc949c1bc",
	"X-RapidAPI-Host": "mashvisor-api.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'message': 'You are not subscribed to this API.'}

# %% [markdown]
# # Webscrape Redfin

# %%
#Links
#page 1
https://www.redfin.com/city/16409/CA/Sacramento?utm_medium=ppc&utm_term=aud-923999260716:kwd-18479583&utm_content=571911945531&utm_campaign=1034079&gclid=Cj0KCQjwoeemBhCfARIsADR2QCtUnYgxvF1rdzy7Wtzu0lM2uALLwk9kDasnq185i-JZK2lPqnnGH5saAqkwEALw_wcB')

#page 2
https://www.redfin.com/city/16409/CA/Sacramento/page-2?utm_medium=ppc&utm_term=aud-923999260716:kwd-18479583&utm_content=571911945531&utm_campaign=1034079&gclid=Cj0KCQjwoeemBhCfARIsADR2QCtUnYgxvF1rdzy7Wtzu0lM2uALLwk9kDasnq185i-JZK2lPqnnGH5saAqkwEALw_wcB
# Out:
#   File "/var/folders/rx/s31g8pg13hbc_gm_qvcw8ht00000gn/T/ipykernel_16117/1061595449.py", line 3
#     https://www.redfin.com/city/16409/CA/Sacramento?utm_medium=ppc&utm_term=aud-923999260716:kwd-18479583&utm_content=571911945531&utm_campaign=1034079&gclid=Cj0KCQjwoeemBhCfARIsADR2QCtUnYgxvF1rdzy7Wtzu0lM2uALLwk9kDasnq185i-JZK2lPqnnGH5saAqkwEALw_wcB')
#           ^
# SyntaxError: invalid syntax

# %%
#Request
from bs4 import BeautifulSoup

r = requests.get('https://www.redfin.com/city/16409/CA/Sacramento/page-2?utm_medium=ppc&utm_term=aud-923999260716:kwd-18479583&utm_content=571911945531&utm_campaign=1034079&gclid=Cj0KCQjwoeemBhCfARIsADR2QCtUnYgxvF1rdzy7Wtzu0lM2uALLwk9kDasnq185i-JZK2lPqnnGH5saAqkwEALw_wcB')

# %%
#Second page to scrape
#https://www.redfin.com/city/16409/CA/Sacramento/page-2?utm_medium=ppc&utm_term=aud-923999260716:kwd-18479583&utm_content=571911945531&utm_campaign=1034079&gclid=Cj0KCQjwoeemBhCfARIsADR2QCtUnYgxvF1rdzy7Wtzu0lM2uALLwk9kDasnq185i-JZK2lPqnnGH5saAqkwEALw_wcB

# %%
#Parse HTML
soup = BeautifulSoup(r.content, 'html.parser')

# %%
#Recieve PRICE OF HOME
prices = []
for idx in range(len(soup.find_all('div', {'class': 'v2 interactive'}))):
    try:
        prices.append(soup.find_all('div', {'class': 'v2 interactive'})[idx].find_all('span', {'class': 'homecardV2Price'})[0].text)
    except:
        pass
#prices

# %%
property_stats = []

for idx in range(len(soup.find_all('div', {'class': 'v2 interactive'}))):
    try:
        property_stats.append((soup.find_all('div', {'class': 'v2 interactive'})[idx].find_all('div', {'class': 'stats'})[0].text.split(' ')[0],
                              soup.find_all('div', {'class': 'v2 interactive'})[idx].find_all('div', {'class': 'stats'})[1].text.split(' ')[0],
                              soup.find_all('div', {'class': 'v2 interactive'})[idx].find_all('div', {'class': 'stats'})[2].text.split(' ')[0]))
#         print(soup.find_all('div', {'class': 'v2 interactive'})[idx].find_all('div', {'class': 'stats'})[0].text.split(' ')[0])
#         print(soup.find_all('div', {'class': 'v2 interactive'})[idx].find_all('div', {'class': 'stats'})[1].text.split(' ')[0])
#         print(soup.find_all('div', {'class': 'v2 interactive'})[idx].find_all('div', {'class': 'stats'})[2].text.split(' ')[0])
#         print()
    except:
        pass
#Bed
#bath
#sqft

# %%
property_names = soup.find_all('div', {'class': 'link-and-anchor'})

# %%
property_df = pd.DataFrame(data=list(zip(property_names, prices, property_stats)), columns=['Property_Name', 'Price', 'Stats'])

# %%
#Cleanse
property_df['Beds'] = property_df['Stats'].apply(lambda i: i[0])
property_df['Baths'] = property_df['Stats'].apply(lambda i: i[1])
property_df['Sqft'] = property_df['Stats'].apply(lambda i: i[2])
property_df['Property_Name'] = property_df['Property_Name'].apply(lambda i: i.text)

# %%
property_df.drop(columns='Stats', axis=1, inplace=True)
property_df
# Out:
#                                        Property_Name       Price Beds Baths  \
# 0          109 River Chase Cir, Sacramento, CA 95864    $728,000    3     2
# 1             5520 Bradford Dr, Sacramento, CA 95820    $365,000    3     1
# 2                 5308 58th St, Sacramento, CA 95820    $320,000    3     1
# 3   5622 Hillsdale Blvd Unit A, Sacramento, CA 95842    $210,000    2   1.5
# 4            520 Santa Ana Ave, Sacramento, CA 95838    $540,000    4     2
# 5               9982 Froom Cir, Sacramento, CA 95827     $49,950    2     1
# 6                  749 41st St, Sacramento, CA 95819  $1,649,000    5     3
# 7                 5451 70th St, Sacramento, CA 95820    $395,000    2     1
# 8                  523 18th St, Sacramento, CA 95811  $1,050,000    5     4
# 9              3320 Sendero St, Sacramento, CA 95838    $344,900    2     1
# 10            4072 Andedon Cir, Sacramento, CA 95826    $436,000    4     2
# 11           224 East Ranch Rd, Sacramento, CA 95825    $495,000    2     2
# 12                 933 3rd Ave, Sacramento, CA 95818    $499,000    2     1
# 13             3585 Damora Ave, Sacramento, CA 95835    $620,000    4     3
# 14           2501 Fernandez Dr, Sacramento, CA 95822    $355,000    3     1
# 15           9145 Rundelay Way, Sacramento, CA 95826    $499,999    3     2
# 16           558 El Camino Ave, Sacramento, CA 95815    $419,900    3     2
# 17        5430 Knotty Pine Way, Sacramento, CA 95835    $485,000    3   2.5
# 18            2245 Portola Way, Sacramento, CA 95818    $719,900    3   1.5
# 19              6023 Stacy Ave, Sacramento, CA 95823    $470,000    4   2.5
# 20        6912 Casa Grande Way, Sacramento, CA 95828    $300,000    3     1
# 21         2764 Riverside Blvd, Sacramento, CA 95818    $749,000    2     1
# 22      8111 Weeping Willow Ln, Sacramento, CA 95828    $450,000    3   2.5
# 23               2354 52nd Ave, Sacramento, CA 95822    $390,000    3     2
# 24              11 Bentley Ave, Sacramento, CA 95823    $189,000    4     2
# 25                2529 27th St, Sacramento, CA 95818  $1,050,000    4     4
# 26           8283 Hayfield Cir, Sacramento, CA 95828    $499,000    4     2
# 27                2915 39th St, Sacramento, CA 95817    $565,000    3     1
# 28               400 Grand Ave, Sacramento, CA 95838    $585,000    6     4
# 29                1401 37th St, Sacramento, CA 95816  $1,575,000    4   3.5
# 30      8684 Crystal River Way, Sacramento, CA 95828    $469,998    3     2
# 31           3104 Churchill Rd, Sacramento, CA 95864    $399,000    3     1
# 32           2608 Cleat Ln #27, Sacramento, CA 95818    $525,000    2   2.5
# 33               716 Morey Ave, Sacramento, CA 95838    $299,000    2     1
# 34                   4630 B St, Sacramento, CA 95819    $675,000    3     1
# 35          2733 Via Villaggio, Sacramento, CA 95864    $559,900    4     3
# 36               1733 63rd Ave, Sacramento, CA 95822    $407,000    3     2
# 37             5846 Meghan Way, Sacramento, CA 95842    $339,900    3     1
# 38           2901 El Prado Way, Sacramento, CA 95825    $475,000    3   1.5
# 39           1720 Berkeley Way, Sacramento, CA 95819  $1,199,000    3     2
#
#      Sqft
# 0   1,694
# 1   1,139
# 2   1,039
# 3     933
# 4   1,100
# 5     690
# 6   3,000
# 7     858
# 8   2,758
# 9   1,028
# 10  1,280
# 11  1,527
# 12  1,057
# 13  2,111
# 14  1,392
# 15  1,288
# 16  1,436
# 17  1,519
# 18  1,350
# 19  1,618
# 20    958
# 21  1,169
# 22  1,538
# 23  1,008
# 24  1,585
# 25  1,930
# 26  1,591
# 27  1,082
# 28  2,156
# 29  2,964
# 30  1,342
# 31  1,081
# 32  1,451
# 33  1,105
# 34  1,107
# 35  2,055
# 36  1,334
# 37  1,007
# 38  1,502
# 39  2,028

# %% [markdown]
# # Final

# %% [markdown]
# #####  #Links
# #page 1
# https://www.redfin.com/city/16409/CA/Sacramento?utm_medium=ppc&utm_term=aud-923999260716:kwd-18479583&utm_content=571911945531&utm_campaign=1034079&gclid=Cj0KCQjwoeemBhCfARIsADR2QCtUnYgxvF1rdzy7Wtzu0lM2uALLwk9kDasnq185i-JZK2lPqnnGH5saAqkwEALw_wcB')
#
# #page 2
# https://www.redfin.com/city/16409/CA/Sacramento/page-2?utm_medium=ppc&utm_term=aud-923999260716:kwd-18479583&utm_content=571911945531&utm_campaign=1034079&gclid=Cj0KCQjwoeemBhCfARIsADR2QCtUnYgxvF1rdzy7Wtzu0lM2uALLwk9kDasnq185i-JZK2lPqnnGH5saAqkwEALw_wcB

# %%
#Request
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %%
#Collect All Pages of Data
prices = []
property_stats = []
property_names_ls = []
for idx in range(1,10):
    if idx < 2:
        url = 'https://www.redfin.com/city/16409/CA/Sacramento?utm_medium=ppc&utm_term=aud-923999260716:kwd-18479583&utm_content=571911945531&utm_campaign=1034079&gclid=Cj0KCQjwoeemBhCfARIsADR2QCtUnYgxvF1rdzy7Wtzu0lM2uALLwk9kDasnq185i-JZK2lPqnnGH5saAqkwEALw_wcB'
    else:
        url = f'https://www.redfin.com/city/16409/CA/Sacramento/page-{idx}?utm_medium=ppc&utm_term=aud-923999260716:kwd-18479583&utm_content=571911945531&utm_campaign=1034079&gclid=Cj0KCQjwoeemBhCfARIsADR2QCtUnYgxvF1rdzy7Wtzu0lM2uALLwk9kDasnq185i-JZK2lPqnnGH5saAqkwEALw_wcB'
        
    #Parse HTML
    r = requests.get(url)
    soup = BeautifulSoup(r.content, 'html.parser')
    
    #Recieve PRICE OF HOME
    for idx1 in range(len(soup.find_all('div', {'class': 'v2 interactive'}))):
        try:
            prices.append(soup.find_all('div', {'class': 'v2 interactive'})[idx1].find_all('span', {'class': 'homecardV2Price'})[0].text)
        except:
            pass
    
    #Gather Property Stats
    for idx2 in range(len(soup.find_all('div', {'class': 'v2 interactive'}))):
        try:
            property_stats.append((soup.find_all('div', {'class': 'v2 interactive'})[idx2].find_all('div', {'class': 'stats'})[0].text.split(' ')[0],
                                  soup.find_all('div', {'class': 'v2 interactive'})[idx2].find_all('div', {'class': 'stats'})[1].text.split(' ')[0],
                                  soup.find_all('div', {'class': 'v2 interactive'})[idx2].find_all('div', {'class': 'stats'})[2].text.split(' ')[0]))
        except:
            pass
    
    property_names = soup.find_all('div', {'class': 'link-and-anchor'})
    property_names_ls = property_names_ls + [x.text for x in property_names]
    
#Convert To DF
property_df = pd.DataFrame(data=list(zip(property_names_ls, prices, property_stats)), columns=['Property_Name', 'Price', 'Stats'])

#Cleanse
property_df['Beds'] = property_df['Stats'].apply(lambda i: i[0])
property_df['Baths'] = property_df['Stats'].apply(lambda i: i[1])
property_df['Sqft'] = property_df['Stats'].apply(lambda i: i[2])

property_df.drop(columns='Stats', axis=1, inplace=True)

# %%
property_df
# Out:
#                                      Property_Name       Price   Beds   Baths  \
# 0                3829 Elm St, Sacramento, CA 95838    $279,900      3       1
# 1    413 Tailoff Ln Unit 91B, Sacramento, CA 95818    $459,900      2     2.5
# 2                  5321 Dana, Sacramento, CA 95822    $525,000      3       2
# 3            4900 Parker Ave, Sacramento, CA 95820    $399,000      4       2
# 4           6735 Tortola Way, Sacramento, CA 95828    $309,000      2       2
# ..                                             ...         ...    ...     ...
# 345                 0 Garden Hwy, Sutter, CA 95837    $257,900  —Beds  —Baths
# 346        5230 Excelsior Rd, Sacramento, CA 95827    $719,000  —Beds  —Baths
# 347    150 Del Verde Cir #98, Sacramento, CA 95833    $219,500      2       1
# 348                3561 N St, Sacramento, CA 95816  $1,299,000      4       2
# 349             3981 8th Ave, Sacramento, CA 95817    $600,000      8     2.5
#
#       Sqft
# 0      918
# 1    1,116
# 2    1,192
# 3    1,502
# 4    1,134
# ..     ...
# 345   0.61
# 346   8.87
# 347    956
# 348  1,260
# 349  2,881
#
# [350 rows x 5 columns]

# %%
for i in range(len(property_df)):
    print(property_df.iloc[i][0])
# Out:
# 3829 Elm St, Sacramento, CA 95838
# 601 Robertson Way, Sacramento, CA 95818
# 2913 Sienna Ln, Sacramento, CA 95864
# 5524 Danjac Cir, Sacramento, CA 95822
# 7660 Bar Du Ln, Sacramento, CA 95829
# 4701 College Oak Dr #13, Sacramento, CA 95841
# 0 Calvine Rd, Sacramento, CA 95829
# 3525 44th St, Sacramento, CA 95817
# 8690 W Stockton Blvd, Elk Grove, CA 95758
# 1626 27th St, Sacramento, CA 95816
# 2729 Swanston Oak Ln, Sacramento, CA 95818
# 7542 Meadowair Way, Sacramento, CA 95822
# 307 Alhambra Blvd, Sacramento, CA 95816
# 0 44th Ave, Sacramento, CA 95824
# 0 44th Ave, Sacramento, CA 95824
# 100 Ford Rd, Sacramento, CA 95838
# 3225 Crocker Dr, Sacramento, CA 95818
# 2658 Alcove Way, Sacramento, CA 95833
# 3128 N St, Sacramento, CA 95816
# 500 J St #1806, Sacramento, CA 95814
# 1611 10th St #2, Sacramento, CA 95814
# 6301 37th Ave, Sacramento, CA 95824
# 952 Q St, Sacramento, CA 95811
# 4216 Bouquet Way, Sacramento, CA 95834
# 5360 15th Ave, Sacramento, CA 95820
# 0 Garden Hwy, Sutter, CA 95837
# 5230 Excelsior Rd, Sacramento, CA 95827
# 150 Del Verde Cir #98, Sacramento, CA 95833
# 3561 N St, Sacramento, CA 95816
# 3981 8th Ave, Sacramento, CA 95817

# %%
addresses = [x for x in property_df['Property_Name']]

# %%
addresses
# Out:
# ['3829 Elm St, Sacramento, CA 95838',
#  '413 Tailoff Ln Unit 91B, Sacramento, CA 95818',
#  '5321 Dana, Sacramento, CA 95822',
#  '4900 Parker Ave, Sacramento, CA 95820',
#  '6735 Tortola Way, Sacramento, CA 95828',
#  '5033 Buffwood Wat, Sacramento, CA 95841',
#  '8865 Skipjack Way, Sacramento, CA 95828',
#  '179 El Camino Ave, Sacramento, CA 95815',
#  '4739 C St, Sacramento, CA 95819',
#  '2830 Rhonda Way, Sacramento, CA 95821',
#  '3605 Alberta Ave, Sacramento, CA 95821',
#  '6611 Benham Way, Sacramento, CA 95831',
#  '1624 P St, Sacramento, CA 95814',
#  '3846 Edison Ave, Sacramento, CA 95821',
#  '2941 Sienna Ln, Sacramento, CA 95864',
#  '500 N St #1108, Sacramento, CA 95814',
#  '68 Kelso Cir, Sacramento, CA 95833',
#  '7213 Roca Way, Sacramento, CA 95842',
#  '1818 - 1818 22nd St #103, Sacramento, CA 95816',
#  '4716 Roosevelt, Sacramento, CA 95820',
#  '0 Balsam St, Sacramento, CA 95838',
#  '5246 J St, Sacramento, CA 95819',
#  '2675 Huntington Rd, Sacramento, CA 95864',
#  '2080 Mangrum Ave, Sacramento, CA 95822',
#  '3288 Ronald Reagan Way, Sacramento, CA 95818',
#  '4049 Ramel Way, Sacramento, CA 95864',
#  '1045 Vanderbilt Way, Sacramento, CA 95825',
#  '9439 Marius Way, Sacramento, CA 95829',
#  '6217 Lurline Ave #112, Sacramento, CA 95841',
#  '2713 Tomato Aly, Sacramento, CA 95818',
#  '8180 Scenic Hills Way, Sacramento, CA 95828',
#  '2891 Herbert Way, Sacramento, CA 95821',
#  '1636 Los Molinos Way, Sacramento, CA 95864',
#  '549 5th Ave, Sacramento, CA 95818',
#  '6680 Golf View Dr, Sacramento, CA 95822',
#  '6501 Kenbridge St, Elk Grove, CA 95758',
#  '821 Larch Ln, Sacramento, CA 95864',
#  '2600 Portola Way, Sacramento, CA 95818',
#  '4964 Diablo Dr, Sacramento, CA 95842',
#  '3925 39th St, Sacramento, CA 95820',
#  '7260 Rush River Dr, Sacramento, CA 95831',
#  '3011 Bedford Falls Way, Sacramento, CA 95818',
#  '8134 Caribbean Way, Sacramento, CA 95826',
#  '7328 Perera Cir, Sacramento, CA 95831',
#  '6041 Garden Hwy, Sacramento, CA 95837',
#  '4218 Guildford Ct, Sacramento, CA 95864',
#  '3809 Downey Way, Sacramento, CA 95817',
#  '3715 Tallyho Dr #10, Sacramento, CA 95826',
#  '2816 F St, Sacramento, CA 95816',
#  '8852 La Riviera Dr Unit B, Sacramento, CA 95826',
#  '2721 Swanston Oak Ln, Sacramento, CA 95818',
#  '4751 D St, Sacramento, CA 95819',
#  '3031 Tice Creek Way, Sacramento, CA 95833',
#  '2609 Capitol Ave, Sacramento, CA 95816',
#  '9086 Leland Ave, Sacramento, CA 95829',
#  '2728 O St, Sacramento, CA 95816',
#  '4713 Amber Ln #3, Sacramento, CA 95841',
#  '3640 Odessa Ln, Sacramento, CA 95834',
#  '657 45th St, Sacramento, CA 95819',
#  '2863 Roseau Way, Sacramento, CA 95833',
#  '6600 - 6604 Stacy Ave, Sacramento, CA 95823',
#  '7045 Cromwell Way, Sacramento, CA 95822',
#  '2272 Bay Horse Ln, Sacramento, CA 95835',
#  '2713 Screech Owl Way, Sacramento, CA 95834',
#  '2410 Larkspur Ln #244, Sacramento, CA 95825',
#  '5 Tinneil Ct, Sacramento, CA 95833',
#  '3636 El Dala Ln, Sacramento, CA 95834',
#  '1613 Dreher St, Sacramento, CA 95811',
#  '8009 Johannisberg Way, Sacramento, CA 95829',
#  '9067 Montoya #1, Sacramento, CA 95826',
#  '6324 Bonanza Dr #126, Sacramento, CA 95842',
#  '5268 Brook Park Ln, Sacramento, CA 95841',
#  '4928 Kingbird Way, Sacramento, CA 95842',
#  '7477 Azimuth Ln #220, Sacramento, CA 95842',
#  '8281 Kossum Way, Elk Grove, CA 95624',
#  '50 Palma Harbour Pl, Sacramento, CA 95834',
#  '5301 E Commerce Way #52104, Sacramento, CA 95835',
#  '1932 Bowling Green Dr, Sacramento, CA 95815',
#  '3003 Trap Rock, Sacramento, CA 95835',
#  '6 Gavilan Ct, Sacramento, CA 95831',
#  '8149 Scenic Hills Way, Sacramento, CA 95828',
#  '8184 Cottonmill Cir, Sacramento, CA 95828',
#  '8659 Forte St, Sacramento, CA 95823',
#  '7500 Monogram Dr, Sacramento, CA 95842',
#  '4409 13th Ave, Sacramento, CA 95820',
#  '300 Perazul Cir, Sacramento, CA 95835',
#  '1813 Cagney Way, Sacramento, CA 95835',
#  '49 Fischbacher St, Sacramento, CA 95816',
#  '3803 Haywood St, Sacramento, CA 95838',
#  '5401 Olympic Way, Sacramento, CA 95842',
#  '535 42nd St, Sacramento, CA 95819',
#  '4200 E Commerce Way #721, Sacramento, CA 95834',
#  '5223 Glimmer Way, Sacramento, CA 95835',
#  '5301 E Commerce Way #54104, Sacramento, CA 95835',
#  '1818 L St #807, Sacramento, CA 95811',
#  '9292 Pearl Bush Ct, Sacramento, CA 95829',
#  '965 Mcclatchy Way, Sacramento, CA 95818',
#  '1828 K St Unit 621R, Sacramento, CA 95811',
#  '2280 NE Hurley Way #84, Sacramento, CA 95825',
#  '111 Creekside Cir, Sacramento, CA 95823',
#  '3805 Domagala St, Sacramento, CA 95834',
#  '2609 Ensenada Way, Sacramento, CA 95815',
#  '441 Olivadi Way, Sacramento, CA 95834',
#  '4200 E Commerce Way #124, Sacramento, CA 95834',
#  '54 Village Green Dr #54, Sacramento, CA 95838',
#  '9125 Dupont, Sacramento, CA 95826',
#  '4522 Jenness Way, Sacramento, CA 95842',
#  '1322 Commons Dr, Sacramento, CA 95825',
#  '9069 Chantal Way, Sacramento, CA 95829',
#  '4009 57th St, Sacramento, CA 95820',
#  '9477 Del Seis Dr, Sacramento, CA 95829',
#  '9480 Del Seis Dr, Sacramento, CA 95829',
#  '9445 Del Seis Dr, Sacramento, CA 95829',
#  '8250 Courage Dr, Sacramento, CA 95829',
#  '2670 Phyllis Ave, Sacramento, CA 95820',
#  '1019 Dornajo Way #115, Sacramento, CA 95825-7324',
#  '4816 Kanob Ct, Sacramento, CA 95842',
#  '4732 67th St, Sacramento, CA 95820',
#  '7881 Caldonia Way, Sacramento, CA 95832',
#  '4869 U St, Sacramento, CA 95817',
#  '2656 3rd St, Sacramento, CA 95818',
#  '410 T St, Sacramento, CA 95811',
#  '8354 Foynes Way, Sacramento, CA 95828',
#  '1227 23rd St, Sacramento, CA 95816',
#  '4400 E Nichols Ave, Sacramento, CA 95820',
#  '508 Woodside Oaks #8, Sacramento, CA 95825',
#  '6821 Capital Cir #206, Sacramento, CA 95828',
#  '2200 - 2204 Downar Way, Sacramento, CA 95838',
#  '1222 Commons Dr, Sacramento, CA 95825',
#  '7465 Havenford Way, Sacramento, CA 95829',
#  '846 Maplegrove Way, Sacramento, CA 95834',
#  '500 Lampasas Ave, Sacramento, CA 95815',
#  '1739 Iverson Way, Sacramento, CA 95835',
#  '4933 Esma Jane Ln, Sacramento, CA 95822',
#  '5655 Verner Oak Ct, Sacramento, CA 95841',
#  '5813 Nona Way, Sacramento, CA 95824',
#  '930 Saverien Dr, Sacramento, CA 95864',
#  '2209 Gila Way, Sacramento, CA 95864',
#  '742 Santa Rita Way, Sacramento, CA 95864',
#  'Undisclosed Address, Sacramento, CA 95841',
#  '2522 Q St, Sacramento, CA 95816',
#  '274 Santiago Ave, Sacramento, CA 95815',
#  '415 Roundtree Ct, Sacramento, CA 95831',
#  '1911 P St, Sacramento, CA 95811',
#  '151 Creekside Cir, Sacramento, CA 95823',
#  '8180 Montevina Dr, Sacramento, CA 95829',
#  '492 Cool Wind Way, Sacramento, CA 95831',
#  '2280 Hurley Way #51, Sacramento, CA 95825',
#  '4909 Esma Jane Ln, Sacramento, CA 95822',
#  '3553 - 3551 Pope Ave, Sacramento, CA 95821',
#  '3217 9th Ave, Sacramento, CA 95817',
#  '8690 W Stockton Blvd, Elk Grove, CA 95758',
#  '1626 27th St, Sacramento, CA 95816',
#  '2729 Swanston Oak Ln, Sacramento, CA 95818',
#  '7542 Meadowair Way, Sacramento, CA 95822',
#  '307 Alhambra Blvd, Sacramento, CA 95816',
#  '0 44th Ave, Sacramento, CA 95824',
#  '0 44th Ave, Sacramento, CA 95824',
#  '100 Ford Rd, Sacramento, CA 95838',
#  '3225 Crocker Dr, Sacramento, CA 95818',
#  '2658 Alcove Way, Sacramento, CA 95833',
#  '3128 N St, Sacramento, CA 95816',
#  '500 J St #1806, Sacramento, CA 95814',
#  '1611 10th St #2, Sacramento, CA 95814',
#  '6301 37th Ave, Sacramento, CA 95824',
#  '952 Q St, Sacramento, CA 95811',
#  '4216 Bouquet Way, Sacramento, CA 95834',
#  '5360 15th Ave, Sacramento, CA 95820',
#  '0 Garden Hwy, Sutter, CA 95837',
#  '5230 Excelsior Rd, Sacramento, CA 95827',
#  '150 Del Verde Cir #98, Sacramento, CA 95833',
#  '3561 N St, Sacramento, CA 95816',
#  '3981 8th Ave, Sacramento, CA 95817']

# %%
import requests

def geocode_address(address, api_key):
    base_url = "https://maps.googleapis.com/maps/api/geocode/json"
    params = {
        "address": address,
        "key": api_key
    }
    response = requests.get(base_url, params=params)
    data = response.json()

    if data['status'] == 'OK':
        location = data['results'][0]['geometry']['location']
        latitude = location['lat']
        longitude = location['lng']
        return latitude, longitude
    else:
        print("Geocoding failed for:", address)
        return None, None

# Replace 'YOUR_API_KEY' with your Google Maps API key
api_key = 'AIzaSyCIjw_3W4zD9mlfxRVCs2fFYSSdJk-SnCo'


coordinates_list = []

for address in addresses:
    lat, lng = geocode_address(address, api_key)
    coordinates_list.append((lat, lng))

# Print the coordinates list
print(coordinates_list)
# Out:
# [(38.6376148, -121.4330962), (38.562863, -121.509165), (38.52678119999999, -121.4890158), (38.5349801, -121.4485819), (38.5048978, -121.4205986), (38.669093, -121.3485154), (38.4769802, -121.3735833), (38.6113154, -121.4625446), (38.5744985, -121.440947), (38.6160731, -121.3863681), (38.6187997, -121.3800037), (38.5065187, -121.5546839), (38.5709909, -121.4872353), (38.6341864, -121.373974), (38.5834838, -121.3927326), (38.5771386, -121.5014846), (38.6264978, -121.4920544), (38.6986255, -121.3338519), (38.5665853, -121.4815765), (38.5335243, -121.4512198), (38.6409983, -121.4305776), (38.5656036, -121.4392258), (38.572033, -121.3985822), (38.5074605, -121.4899239), (38.5443817, -121.4838902), (38.57507, -121.369485), (38.5642968, -121.4149798), (38.458055, -121.3494698), (38.6795879, -121.3294786), (38.5625769, -121.4749637), (38.4614344, -121.4040301), (38.6178958, -121.4081828), (38.594558, -121.3758053), (38.5637629, -121.5085515), (38.6283734, -121.3998767), (38.5586406, -121.3919), (38.6792715, -121.5046365), (38.646383, -121.4537964), (38.50270450000001, -121.47898), (38.5094444, -121.4920544), (38.6829948, -121.3492978), (38.5622634, -121.4077316), (38.5256835, -121.4145741), (38.5266682, -121.4389681), (38.6703702, -121.359623), (38.6582382, -121.4535308), (38.5792031, -121.3205417), (38.5716354, -121.4500593), (38.5261164, -121.4215
0-py3-none-any.whl (24 kB)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/Mirzafamily/opt/anaconda3/lib/python3.9/site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/Mirzafamily/opt/anaconda3/lib/python3.9/site-packages (from requests->folium) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/Mirzafamily/opt/anaconda3/lib/python3.9/site-packages (from requests->folium) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/Mirzafamily/opt/anaconda3/lib/python3.9/site-packages (from requests->folium) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/Mirzafamily/opt/anaconda3/lib/python3.9/site-packages (from requests->folium) (2.0.4)
# Installing collected packages: branca, folium
# Successfully installed branca-0.6.0 folium-0.14.0
# Note: you may need to restart the kernel to use updated packages.

# %%
lat_list = [lat for lat, lng in coordinates_list]
lng_list = [lng for lat, lng in coordinates_list]

# %%
property_df['latitude'] = lat_list
property_df['longitude'] = lng_list

# Print the updated DataFrame
property_df
# Out:
#                                      Property_Name       Price   Beds   Baths  \
# 0                3829 Elm St, Sacramento, CA 95838    $279,900      3       1
# 1    413 Tailoff Ln Unit 91B, Sacramento, CA 95818    $459,900      2     2.5
# 2                  5321 Dana, Sacramento, CA 95822    $525,000      3       2
# 3            4900 Parker Ave, Sacramento, CA 95820    $399,000      4       2
# 4           6735 Tortola Way, Sacramento, CA 95828    $309,000      2       2
# ..                                             ...         ...    ...     ...
# 345                 0 Garden Hwy, Sutter, CA 95837    $257,900  —Beds  —Baths
# 346        5230 Excelsior Rd, Sacramento, CA 95827    $719,000  —Beds  —Baths
# 347    150 Del Verde Cir #98, Sacramento, CA 95833    $219,500      2       1
# 348                3561 N St, Sacramento, CA 95816  $1,299,000      4       2
# 349             3981 8th Ave, Sacramento, CA 95817    $600,000      8     2.5
#
#       Sqft   latitude   longitude
# 0      918  38.637615 -121.433096
# 1    1,116  38.562863 -121.509165
# 2    1,192  38.526781 -121.489016
# 3    1,502  38.534980 -121.448582
# 4    1,134  38.504898 -121.420599
# ..     ...        ...         ...
# 345   0.61  38.715344 -121.606629
# 346   8.87  38.529951 -121.298967
# 347    956  38.626151 -121.500983
# 348  1,260  38.567646 -121.460257
# 349  2,881  38.544807 -121.461234
#
# [350 rows x 7 columns]

# %%
map_center = (property_df['latitude'][0], property_df['longitude'][0])
mymap = folium.Map(location=map_center, zoom_start=12)

# Add markers with pop-up details for each property
for index, row in property_df.iterrows():
    property_name = row['Property_Name']
    price = row['Price']
    beds = row['Beds']
    baths = row['Baths']
    sqft = row['Sqft']
    latitude = row['latitude']
    longitude = row['longitude']

    popup_html = f'''
    <div style="font-size: 10px; width: 300px;">
        <b>{property_name}</b><br>
        Price: <span style="color: red"> {price}</span><br>
        Beds: {beds}<br>
        Baths: {baths}<br>
        Sqft: {sqft}<br>
        Latitude: {latitude}<br>
        Longitude: {longitude}
    </div>
    '''

    icon = folium.Icon(
        icon="home", 
        color="blue",  
        icon_size=(30, 40),
        prefix="fa"
    )
    folium.Marker(location=(latitude, longitude), icon=icon, popup=popup_html, size = 10).add_to(mymap)

# Save the map to an HTML file
mymap.save("property_map1.html")

# Open the map in your default web browser
import webbrowser
webbrowser.open("property_map1.html")
# Out:
# True
